# %%
import numpy as np
import pandas as pd

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 42.5 MB/s eta 0:00:00
# ...

# %%
import gensim
import os

# %%
pip install nltk

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ad57ab0-9257-4927-b0bb-6529732a97ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ad57ab0-9257-4927-b0bb-6529732a97ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
files_list = os.listdir()
print(files_list)
# Out:
# ['.config', '005ssb.txt', '003ssb.txt', '001ssb.txt', '004ssb.txt', '002ssb.txt', 'sample_data']

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
story = []

for filename in os.listdir():
    if filename.endswith(".txt"):

        with open(filename, "r", encoding="latin-1") as f:
            corpus = f.read()

            raw_sent = sent_tokenize(corpus)

            for sent in raw_sent:
                story.append(simple_preprocess(sent))

print(len(story))
print(story[:5])
# Out:
# 145020
# ...

# %%
model=gensim.models.Word2Vec(window=10,min_count=2)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (6568873, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7954155802726746),
#  ('targaryen', 0.7589145302772522),
#  ('unburnt', 0.7417223453521729),
#  ('queen', 0.7254709005355835),
#  ('princess', 0.7010886073112488),
#  ('myrcella', 0.6939215660095215),
#  ('dorne', 0.6746805310249329),
#  ('elia', 0.6559170484542847),
#  ('margaery', 0.6521140336990356),
#  ('westeros', 0.6503821611404419)]

# %%
model.wv.doesnt_match(['jon','rikon','arya','sansa','bran'])
# Out:
# WARNING:gensim.models.keyedvectors:vectors for words {'rikon'} are not present in the model, ignoring these words
# 'jon'

# %%
model.wv.doesnt_match(['cersei','jaime','tyrion','sansa',])
# Out:
# 'sansa'

# %%
model.wv.doesnt_match(['jon','arya','sansa','bran'])
# Out:
# 'jon'

# %%
model.wv['king'].shape
# Out:
# (100,)

# %%
model.wv.similarity('cersei','tyrion')
# Out:
# np.float32(0.6569533)

# %%
model.wv.similarity('cersei','jaime')
# Out:
# np.float32(0.743986)

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.01679719, -0.13445368,  0.17531586, ..., -0.05675519,
#         -0.19284815,  0.166098  ],
#        [-0.0493429 , -0.08621745,  0.07225817, ..., -0.09052043,
#         -0.03095637,  0.12483656],
#        [ 0.1273341 , -0.00616018, -0.07049928, ...,  0.00052628,
#          0.06888818, -0.18384081],
#        ...,
#        [-0.00812276,  0.10954324, -0.0145058 , ..., -0.14999583,
#          0.06663709,  0.02973301],
#        [ 0.01838038,  0.14006013,  0.0208352 , ..., -0.09590404,
#          0.10908273,  0.03392011],
#        [ 0.00766018,  0.09551014,  0.01888034, ..., -0.08287849,
#          0.02613768,  0.0160987 ]], dtype=float32)

# %%
y=model.wv.index_to_key

# %%
from sklearn.decomposition import PCA

# %%
PCA=PCA(n_components=3)

# %%
X=PCA.fit_transform(model.wv.get_normed_vectors())

# %%
X[ :5]
# Out:
# array([[ 0.14514856, -0.59521663,  0.05577065],
#        [ 0.20271294, -0.33017558, -0.05092327],
#        [-0.30699372, -0.5676509 , -0.20815206],
#        [ 0.00135046, -0.36705   ,  0.12848406],
#        [-0.14333262, -0.56311405, -0.2288593 ]], dtype=float32)

# %%
X.shape
# Out:
# (17453, 3)

# %%
import plotly.express as py

# %%
fig=py.scatter_3d(X[:500],x=0,y=1,z=2, color=y[:500])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
files.download('word2vec.model')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1951/486344724.py in <cell line: 0>()
# ----> 1 files.download('word2vec.model')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: word2vec.model
